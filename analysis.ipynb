# %%
import pandas as pd
# Out:
# C:\Users\otter\AppData\Local\Temp\ipykernel_30800\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
api_key = 'RGAPI-2f6f13fa-239a-4a9e-83c4-5a764ebd894d'

# %%
api_url = 'https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/LightningKnight'

# %%
import requests

# %%
api_url = api_url + '?api_key=' + api_key

# %%
requests.get(api_url)
# Out:
# <Response [200]>

# %%
resp = requests.get(api_url)
player_info = resp.json()
player_info
# Out:
# {'id': 'Oj5z3KRnvJvKJhmr5Jfs0r1u80AI97o_SKupINcGyVzxeC93',
#  'accountId': '5q82z59DXBEmOPSxSlhXKky-_oQsY-UTYEylA5xdYIF5PnMq2wnpepAM',
#  'puuid': 'Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg',
#  'name': 'LightningKnight',
#  'profileIconId': 6473,
#  'revisionDate': 1708288051018,
#  'summonerLevel': 415}

# %%
puuid = player_info['puuid']
puuid
# Out:
# 'Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg'

# %%
api_url = 'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg/ids?start=0&count=100'

# %%
api_url = api_url + '&api_key=' + api_key
api_url
# Out:
# 'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg/ids?start=0&count=100&api_key=RGAPI-2f6f13fa-239a-4a9e-83c4-5a764ebd894d'

# %%
resp = requests.get(api_url)
match_ids = resp.json()

match_ids
# Out:
# ['NA1_4926006174',
#  'NA1_4925975967',
#  'NA1_4925949849',
#  'NA1_4925113905',
#  'NA1_4925061795',
#  'NA1_4925026917',
#  'NA1_4924591399',
#  'NA1_4924545748',
#  'NA1_4924490929',
#  'NA1_4924424539',
#  'NA1_4924364507',
#  'NA1_4924274461',
#  'NA1_4924249902',
#  'NA1_4924205110',
#  'NA1_4923646359',
#  'NA1_4923607706',
#  'NA1_4923552682',
#  'NA1_4923504718',
#  'NA1_4923297911',
#  'NA1_4923266195',
#  'NA1_4922717014',
#  'NA1_4922530930',
#  'NA1_4922507096',
#  'NA1_4922273781',
#  'NA1_4922248263',
#  'NA1_4921858281',
#  'NA1_4921799330',
#  'NA1_4921757542',
#  'NA1_4921536169',
#  'NA1_4921496399',
#  'NA1_4921469134',
#  'NA1_4920741708',
#  'NA1_4920705040',
#  'NA1_4920646511',
#  'NA1_4920608233',
#  'NA1_4920104394',
#  'NA1_4920072692',
#  'NA1_4920053113',
#  'NA1_4919534076',
#  'NA1_4918982662',
#  'NA1_4918550147',
#  'NA1_4918451655',
#  'NA1_4918415359',
#  'NA1_4918377375',
#  'NA1_4917985883',
#  'NA1_4917942621',
#  'NA1_4917908705',
# ...

# %%
recent_match = match_ids[0]
recent_match
# Out:
# 'NA1_4926006174'

# %%
api_url = 'https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4925949849'
api_url = api_url + '?api_key=' + api_key

# %%
resp = requests.get(api_url)
match_data = resp.json()

match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4925949849',
#   'participants': ['xRC0gyqREPLZZ81dLoBvfHUIMSsJUpDTxvAqCMPC5lI4QHVOlrokxE5jDhUgDLL823c9rILR9QCQGQ',
#    'GSxGt1PJ5-ryeQup2GpBPDiBcjJ-kK31PofWkssreXhIF0GzskiQKYMnVa6N7_EL5HOqWV2xXTX6aw',
#    'Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg',
#    'sJIgNgRqPw1xf-JoM4Vdn9eQStjmrHVkqPldUOFyOXA1F3Gj9J0rtiaNDhJY_dUgXNy01okuIMldRw',
#    'Zs6hoD8DO7swROsrVVNpM6WJGKlxibOuSUbn16S80Zm8eLrG8N2ieIXxAyZJ8DV-zXSkkYy1IR1kTA',
#    'yuFs47087QVBhhsuWPEQTskMhAol7_NR1PQjVpzBVstso2iG0n3TeC3Wuzp9Ak-5V1P4gNzx9jI2Fw',
#    'RYhnVhoMMxUC5OgtFK1ByFLBW1CeLGfKNIFwbzYCJOkQPNkMRwqn1NzWq6zCVbNUODBo6VD3jY9QGw',
#    'QgPzX5rrDLRVIB2z9trEY5bsVdyN_S2hXkNAgIv1vMfkXFhxg5vlxTD8uoixDkSU2KpXY0h1I1PNfw',
#    'gsPT6Ah0ARppxZ2rIkYucqoDY3ynuTlitPwwBjC9wQXJOUqz2mghtSfiX4qdV6Qt4umxo1aoLZE-jg',
#    'SCeFTrlABYD1nvKhUb35Q9-6lC4lREmz28qGMWR0rowQcjChN3aIzQMoxw6f0NxJd6o8ZFicL9ld5Q']},
# ...

# %%
match_data.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
player_data = match_data['info']['participants'][0]
player_data
# Out:
# {'allInPings': 0,
#  'assistMePings': 1,
#  'assists': 5,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 7,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 259,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronBuffGoldAdvantageOverThreshold': 1,
#   'baronTakedowns': 1,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7028510402408733,
#   'controlWardsPlaced': 1,
#   'damagePerMinute': 922.0159594847605,
#   'damageTakenOnTeamPercentage': 0.20862175785135684,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 0,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 1,
#   'earliestBaron': 1241.3381771,
#   'earliestDragonTakedown': 1007.8474828999999,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
# ...

# %%
k = player_data['kills']
d = player_data['deaths']
a = player_data['assists']
print("Kills:", k)
print("Deaths:", d)
print("Assists:", a)
print("KDA:", (k + a))
# Out:
# Kills: 7
# Deaths: 0
# Assists: 5
# KDA: 12

# %%
# A list of all the participants puuids
participants = match_data['metadata']['participants']
# Now, find where in the data our players puuid is found
player_index = participants.index(puuid)
player_index
# Out:
# 2

# %%
participants[player_index]
# Out:
# 'Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg'

# %%
match_data['info']['participants'][player_index]['summonerName']
# Out:
# 'LightningKnight'

# %%
def get_puuid(summoner_name, region, api_key):
    api_url = (
        "https://" + 
        region +
        ".api.riotgames.com/lol/summoner/v4/summoners/by-name/" +
        summoner_name +
        "?api_key=" +
        api_key
    )
    
    print(api_url)
    
    resp = requests.get(api_url)
    player_info = resp.json()
    puuid = player_info['puuid']
    return puuid

# %%
summoner_name = 'LightningKnight'
region = 'na1'

puuid = get_puuid(summoner_name, region, api_key)
puuid
# Out:
# https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/LightningKnight?api_key=RGAPI-2f6f13fa-239a-4a9e-83c4-5a764ebd894d
# 'Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg'

# %%
def get_match_ids(puuid, mass_region, api_key):
    api_url = (
        "https://" +
        mass_region +
        ".api.riotgames.com/lol/match/v5/matches/by-puuid/" +
        puuid + 
        "/ids?queue=420&start=0&count=70" + 
        "&api_key=" + 
        api_key
    )
    
    print(api_url)
    
    resp = requests.get(api_url)
    match_ids = resp.json()
    return match_ids

# %%
# NOTE: region and mass_region are different
# for instance, NA1 is the North American region
# which is part of the AMERICAS mass region
# EUW1 is Europe West region, part of the EUROPE mass region
mass_region = 'AMERICAS'

match_ids = get_match_ids(puuid, mass_region, api_key)
match_ids
# Out:
# https://AMERICAS.api.riotgames.com/lol/match/v5/matches/by-puuid/Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg/ids?queue=420&start=0&count=70&api_key=RGAPI-2f6f13fa-239a-4a9e-83c4-5a764ebd894d
# ['NA1_4926006174',
#  'NA1_4925975967',
#  'NA1_4925949849',
#  'NA1_4925113905',
#  'NA1_4925061795',
#  'NA1_4925026917',
#  'NA1_4924545748',
#  'NA1_4924490929',
#  'NA1_4924424539',
#  'NA1_4924364507',
#  'NA1_4924274461',
#  'NA1_4924249902',
#  'NA1_4924205110',
#  'NA1_4923552682',
#  'NA1_4923504718',
#  'NA1_4923297911',
#  'NA1_4923266195',
#  'NA1_4922717014',
#  'NA1_4922530930',
#  'NA1_4922507096',
#  'NA1_4922273781',
#  'NA1_4922248263',
#  'NA1_4921858281',
#  'NA1_4921799330',
#  'NA1_4921757542',
#  'NA1_4921536169',
#  'NA1_4921496399',
#  'NA1_4921469134',
#  'NA1_4920741708',
#  'NA1_4920705040',
#  'NA1_4920646511',
#  'NA1_4920608233',
#  'NA1_4920104394',
#  'NA1_4920072692',
#  'NA1_4920053113',
#  'NA1_4919534076',
# ...

# %%
# From a given match ID and mass region, get the data about the game
def get_match_data(match_id, mass_region, api_key):
    api_url = (
        "https://" + 
        mass_region + 
        ".api.riotgames.com/lol/match/v5/matches/" +
        match_id + 
        "?api_key=" + 
        api_key
    )
    
    resp = requests.get(api_url)
    match_data = resp.json()
    return match_data

# %%
match_id = match_ids[0]
match_data = get_match_data(match_id, mass_region, api_key)
match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4926006174',
#   'participants': ['vWPAXqbaCfgDTO4Mcv2xsQsFlIEacAQGI1vvY2alOIwxiQw4yxy6tKTqLXVElZ30TZnRteembJ9nbQ',
#    'GSxGt1PJ5-ryeQup2GpBPDiBcjJ-kK31PofWkssreXhIF0GzskiQKYMnVa6N7_EL5HOqWV2xXTX6aw',
#    'Ry2ICMxuiv2TrVXKop-z8qOvMGjBUnUc0L0p_Xpwb60DXfUCH9fS1xkx8J5Q4jrkzPWb0O5bZCobpg',
#    'xAuR03X_MH7d2sf0N6MwruDVO1JSNHdKr35xU2F7t66PO9-nFfiSU6eN1ugxTxdQXRD5wAnRn5FBWw',
#    'llGPhKoX5I56ghfiszcJKetUJYqRH_j4ZMxLFOZyYlbSC8uopjvmURDlcSBK4IrweHLCYBrV6aFYsQ',
#    '9m0ch1GUVK4vg7BMl_oNp2haUdEI-qzoVdU44rg4WIsM0V_TwSufyExsqTa66-q61RljNJTvSME0zw',
#    'bM5L7nr0cqnLRCf4pCFe8N5FYZVxHeAQ8u5ggMDDAQn0q50sUHUG0q0HMwdZBIcrok1fQ-UXquHHTg',
#    '8UEGUxqJ9B4Lp7jzybpkSSiPsBUU0yg-TKtT2q0FbMm1uVpcJGCP1B2A4Qnj9EY1-t6zEd_C1sowAg',
#    'txELrRHdPO4yuY0hRjUI4-CGwRNer61rPF9w65QlnjxcHTOkp-KXbQn9z4p3wDMTiKoXqgkdbH_qCg',
#    'Sb0KQVEFAzLvKBkrisMtmeopZNk6NZ1OXonZktu20mLT1ESqEboUsYCiFKYs4URZjgb1NJko0Qopdw']},
# ...

# %%
# Given the match data and a players puuid, return the data about just them
def find_player_data(match_data, puuid):
    participants = match_data['metadata']['participants']
    player_index = participants.index(puuid)
    player_data = match_data['info']['participants'][player_index]
    return player_data

# %%
temp_data = find_player_data(match_data, puuid)

# %%
def clean_dict(dirty_dict):

  entries_to_remove = ('challenges', 'playerScore0','playerScore1','playerScore10',
                  'playerScore11','playerScore2','playerScore3', 'playerScore4',
                    'playerScore5', 'playerScore6', 'playerScore7', 'playerScore8',
                      'playerScore9' )
  for i in entries_to_remove:
          dirty_dict.pop(i,None)
  return(dirty_dict)

# %%
data = pd.DataFrame(columns= clean_dict(temp_data).keys(), index=match_ids)

for match_id in match_ids:
    
    print(match_id)
    
    # run the two functions to get the player data from the match ID
    match_data = get_match_data(match_id, mass_region, api_key)
    player_data = find_player_data(match_data, puuid)
    clean_data = clean_dict(player_data)
    data.loc[match_id] = clean_data

data
# Out:
# NA1_4926006174
# NA1_4925975967
# NA1_4925949849
# NA1_4925113905
# NA1_4925061795
# NA1_4925026917
# NA1_4924545748
# NA1_4924490929
# NA1_4924424539
# NA1_4924364507
# NA1_4924274461
# NA1_4924249902
# NA1_4924205110
# NA1_4923552682
# NA1_4923504718
# NA1_4923297911
# NA1_4923266195
# NA1_4922717014
# NA1_4922530930
# NA1_4922507096
# NA1_4922273781
# NA1_4922248263
# NA1_4921858281
# NA1_4921799330
# NA1_4921757542
# NA1_4921536169
# NA1_4921496399
# NA1_4921469134
# NA1_4920741708
# NA1_4920705040
# NA1_4920646511
# NA1_4920608233
# NA1_4920104394
# NA1_4920072692
# NA1_4920053113
# NA1_4919534076
# NA1_4918982662
# NA1_4918550147
# NA1_4918451655
# NA1_4918415359
# NA1_4918377375
# NA1_4917942621
# NA1_4917908705
# NA1_4917866397
# NA1_4917842031
# NA1_4917809164
# NA1_4917746328
# NA1_4917422815
# NA1_4916855418
# NA1_4916818940
# NA1_4915867249
# NA1_4914843344
# NA1_4913884456
# NA1_4913790305
# NA1_4913720084
# NA1_4913647059
# NA1_4911530059
# NA1_4911474005
# ...

# %%
data.to_csv('Data/gameData.csv', index = True)
